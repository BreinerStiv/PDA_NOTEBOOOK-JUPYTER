# %% [markdown]
# ##Ejercicios de práctica Fundamentos Python (3)

# %%
#EJERCICIO 1
#Complete la palabra clave que define una función

def saludar():
  print("Hola")

saludar()
# Out:
# Hola

# %%
#EJERCICIO 2
#Complete la línea que ejecuta la función ya definida

def bienvenida ():
  print("Bienvenido al curso")

bienvenida()
# Out:
# Bienvenido al curso

# %%
#EJERCICIO 3
#Sin ejecutar, determine en qué orden aparecen los mensajes

def uno():
  print("A")

print("B")
uno()
print("C")
# Out:
# B
# A
# C

# %%
##EJERCICIO 4
#El programa falla porque la función se llama antes de existir. Reescriba las líneas en el orden correcto.


def saludar(nombre):
  print("Hola,", nombre)

saludar("Ana")
# Out:
# Hola, Ana

# %%
##EJERCICIO 5
#Complete el parámetro que recibe la función.


def saludar(nombre):
  print("Hola,", nombre)

saludar("Ana")
# Out:
# Hola, Ana

# %%
#EJERCICIO 6
#Llame tres veces a la misma función, cada vez con un precio distinto.


def con_iva(precio):
  return precio * 1.19

print(con_iva(30000))
print(con_iva(25000))
print(con_iva(100000))
# Out:
# 35700.0
# 29750.0
# 119000.0

# %%
#EJERCICIO 7
#Complete los dos parámetros que la función necesita

def area(base, altura):
  return base * altura

print(area(3, 4))
# Out:
# 12

# %%
#EJERCICIO 8
#Complete los argumentos para obtener exactamente el resultado indicado

def ara(base, altura):
  return base * altura

print(area(5, 5),)  #25.0
# Out:
# 25

# %%
#EJERCICIO 9
#Observe la definición y la llamada, y distinga cada uno de los dos

def doble(n):
  return n * 2

resultado = doble(5)

## n: es el parametro ;  5: es el argumento

# %%
#EJERCICIO 10
#Complete la llamada para que se imprima: Ana 20 Bogota

def perfil(nombre, edad, ciudad):
  print(nombre, edad, ciudad )

perfil("Ana", 20, "Bogota")
# Out:
# Ana 20 Bogota

# %%
#EJERCICIO 11
#Complete los nombres de los parámetros para que el orden deje de imporTAR

def perfil(nombre, edad, ciudad):
  print(nombre, edad, ciudad )

perfil( edad=20, nombre="Ana", ciudad="Bogota")
# Out:
# Ana 20 Bogota

# %%
#EJERCICIO 12
#Complete el valor por defecto del parámetro saludo.

def saludar(nombre, saludo="Hola"):
  print(saludo, nombre)

saludar("Ana")
# Out:
# Hola Ana

# %%
#EJERCICIO 13
#Complete la palabra clave que entrega el resultado

def doble(n):
  return n * 2

print(doble(5))
# Out:
# 10

# %%
#EJERCICIO 14
#Complete la llamada para guardar el resultado y operar con él.

def doble(n):
  return n * 2

resultado = doble(6)
print(resultado + 1)
# Out:
# 13

# %%
#EJERCICIO 15
#Sin ejecutar, determine qué imprimen las dos últimas líneas.

def saludo(nombre):
  print("Hola,", nombre)

x = saludo("Ana")
print(x)

# Como esta funcion NO tiene return, esta funcion arroja al final None automaticamente
# Out:
# Hola, Ana
# None

# %%
#EJERCICIO 16
#La suma falla porque la función no devuelve nada. Escriba la versión corregida de la funcion.

def doble(n):
  return n * 2

total = doble(5) + 3
print(total)
# Out:
# 13

# %%
#EJERCICIO 17
#Complete la instrucción que devuelve el segundo resultado

def signo(n):
  if n < 0 :
    return "negativo"
  else:
    return "positivo"

print(signo(-4))
print(signo(7))
# Out:
# negativo
# positivo

# %%
#EJERCICIO 18
#Complete la función que calcula el promedio de una lista de notas.

def promedio(notas):
  total = 0
  for n in notas:
    total = total + n
  return total / len(notas)

print(promedio([3.5, 4.2, 2.8]))
# Out:
# 3.5

# %%
#EJERCICIO 19
#Sin ejecutar, determine qué imprime cada una de las dos últimas líneas.

mensaje = "global"

def prueba():
  mensaje = "local"
  print(mensaje)

prueba()
print(mensaje)
# Out:
# local
# global

# %%
#EJERCICIO 20
#Complete el programa que calcula el promedio de un estudiante y muestra si aprueba,usando dos funciones.


def promedio(notas):
  total = 0
  for n in notas:
    total = total + n
  return total / len(notas)

def reporte (nombre, notas):
  prom = promedio(notas)
  print(nombre, round(prom, 2))
  if prom >=3.0:
    print("Aprobado")
  else:
    print("No aprobado")

reporte ("Laura", [3.5, 4.2, 2.8])
# Out:
# Laura 3.5
# Aprobado
